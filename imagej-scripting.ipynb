// %% [markdown]
//  ![image.png](attachment:image.png)

// %% [markdown]
// # Scripting in ImageJ
//
//
// <small>
//
// Jan Eglinger
//
// Facility for Advanced Imaging and Microscopy (FAIM)
//
// FMI Basel
//
// </small>

// %% [markdown]
// ![ImageJ Toolbar](./images/imagej-toolbar.png)

// %% [markdown]
// ## Topics
//
// ### Introduction
//
// * Introduction to ImageJ Macro language
// * Using the Macro Recorder
// * Using the Script Editor
//
// ### Batch Processing
//
// * Processing multiple images
// * Making your script generic

// %% [markdown]
// ## Scripting in ImageJ
//
// * Processing multiple images/files
// * Reproducibility
// * Robustness

// %% [markdown]
// ## Scripting in ImageJ

// %% [markdown]
// ## Scripting in ImageJ

// %% [markdown]
// ## Scripting in ImageJ

// %% [markdown]
// ## Scripting in ImageJ
